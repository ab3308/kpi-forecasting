# %% [markdown]
# # Spreadsheet columns
# - Publisher - org displaying the ad
# - Advertiser - brand paying for ad
# - Campaign - marketing initiative
# - Imps - number of times displayed regardless of views
# - Viewable imps - times ad is visible on screen
# - Clicks - num clicks
# - Dsp total cost USD - cost for advertiser to place ads along with platform fees etc
# - Dsp media cost USD - cost for advertiser to place ads
# - Ssp media cost USD - fee (%) taken by publisher on any revenue generated by ads
#     - is this separate to display side platform costs?
# - Pc convs - conversions after click
# - Total convs - conversions
# - Adstxt verified imps - confirmed seen by real person

# %%
import numpy as np
import pandas as pd
import catboost as cb
import sklearn as sk

# %%
dataset = "../data/dataset.csv"
df = pd.read_csv(dataset, index_col=None, thousands=',')
df.dtypes
# Out:
#               Datetime                     Publisher Advertiser Campaign  \
# 0  2021-04-18 05:00:00         Undisclosed publisher    Brand B       B7
# 1  2021-04-18 05:00:00  Ushodaya Enterprises Pvt Ltd    Brand B       B5
# 2  2021-04-18 05:00:00                     Network18    Brand B       B7
# 3  2021-04-18 05:00:00              Mail Metro Media    Brand B       B6
# 4  2021-04-18 05:00:00         Undisclosed publisher    Brand B       B5
#
#    Imps  Viewable Imps  Clicks  Dsp Total Cost USD  Dsp Media Cost USD  \
# 0   234              0       0               17.89               15.88
# 1    27              0       0                1.65                1.47
# 2    27              0       0                0.51                0.42
# 3    17              0       0                0.46                0.41
# 4   107              0       1                3.26                2.82
#
#    Ssp Media Cost USD  ...  Day of week  Hour of day  VerifiedImpRate  \
# 0               11.45  ...            6            5         0.713675
# 1                1.12  ...            6            5         0.222222
# 2                0.31  ...            6            5         1.000000
# 3                0.32  ...            6            5         0.764706
# 4                2.05  ...            6            5         0.738318
#
#    ConvPerVerImp  SspCostPerConv  SspCostPerVerImp  DspTotalCostPerConv  \
# 0            0.0             NaN          0.068563                  NaN
# 1            0.0             NaN          0.186667                  NaN
# 2            0.0             NaN          0.011481                  NaN
# 3            0.0             NaN          0.024615                  NaN
# 4            0.0             NaN          0.025949                  NaN
#
#    DspTotalCostPerVerImp  OverallCostPerConv  OverallCostPerVerImp
# 0               0.107126                 NaN              0.175689
# 1               0.275000                 NaN              0.461667
# 2               0.018889                 NaN              0.030370
# 3               0.035385                 NaN              0.060000
# 4               0.041266                 NaN              0.067215
#
# [5 rows x 23 columns]

# %% [markdown]
# # Set dtypes

# %%
df["Datetime"] = pd.to_datetime(df["Datetime"])
df["Publisher"]
df.dtypes

# %% [markdown]
# # Convert datetime to day of week and hour of day

# %%
day, hour = df["Datetime"].dt.dayofweek, df["Datetime"].dt.hour

df["Day of week"] = day.astype(int)
df["Hour of day"] = hour.astype(int)

# %% [markdown]
# # Add verified impression rate

# %%
df["VerifiedImpRate"] = df["Adstxt Verified Imps"].astype(int) / df["Imps"].astype(int)

# %% [markdown]
# # Add conversion / verified impression rate

# %%
df["ConvPerVerImp"] = df["Total Convs"].astype(int) / df["Adstxt Verified Imps"].astype(int)

# %% [markdown]
# ### Ssp rates

# %%
df["SspCostPerConv"] = df["Ssp Media Cost USD"].astype(float) / df["Total Convs"].astype(int)
df["SspCostPerVerImp"] = df["Ssp Media Cost USD"].astype(float) / df["Adstxt Verified Imps"].astype(int)

# %% [markdown]
# ### Dsp rates

# %%
# Dsp total cost per conversion
df["DspTotalCostPerConv"] = df["Dsp Total Cost USD"].astype(float) / df["Total Convs"].astype(int)

# Dsp total cost per verified impression
df["DspTotalCostPerVerImp"] = df["Dsp Total Cost USD"].astype(float) / df["Adstxt Verified Imps"].astype(int)

# %% [markdown]
# # Overall rates

# %%
# Overall cost per conversion (dsp total and ssp)
df["OverallCostPerConv"] = df["DspTotalCostPerConv"].astype(float) + df["SspCostPerConv"].astype(float)

# cost per verified impression
df["OverallCostPerVerImp"] = df["DspTotalCostPerVerImp"].astype(float) + df["SspCostPerVerImp"].astype(float)

# %% [markdown]
# # Handle infinite values and save csv

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.to_csv(dataset, index=False)

# %%
df.head()
# Out:
#              Datetime                     Publisher Advertiser Campaign  Imps  \
# 0 2021-04-18 05:00:00         Undisclosed publisher    Brand B       B7   234
# 1 2021-04-18 05:00:00  Ushodaya Enterprises Pvt Ltd    Brand B       B5    27
# 2 2021-04-18 05:00:00                     Network18    Brand B       B7    27
# 3 2021-04-18 05:00:00              Mail Metro Media    Brand B       B6    17
# 4 2021-04-18 05:00:00         Undisclosed publisher    Brand B       B5   107
#
#    Viewable Imps  Clicks  Dsp Total Cost USD  Dsp Media Cost USD  \
# 0              0       0               17.89               15.88
# 1              0       0                1.65                1.47
# 2              0       0                0.51                0.42
# 3              0       0                0.46                0.41
# 4              0       1                3.26                2.82
#
#    Ssp Media Cost USD  ...  Day of week  Hour of day  VerifiedImpRate  \
# 0               11.45  ...            6            5         0.713675
# 1                1.12  ...            6            5         0.222222
# 2                0.31  ...            6            5         1.000000
# 3                0.32  ...            6            5         0.764706
# 4                2.05  ...            6            5         0.738318
#
#    ConvPerVerImp  SspCostPerConv  SspCostPerVerImp  DspTotalCostPerConv  \
# 0            0.0             NaN          0.068563                  NaN
# 1            0.0             NaN          0.186667                  NaN
# 2            0.0             NaN          0.011481                  NaN
# 3            0.0             NaN          0.024615                  NaN
# 4            0.0             NaN          0.025949                  NaN
#
#    DspTotalCostPerVerImp  OverallCostPerConv  OverallCostPerVerImp
# 0               0.107126                 NaN              0.175689
# 1               0.275000                 NaN              0.461667
# 2               0.018889                 NaN              0.030370
# 3               0.035385                 NaN              0.060000
# 4               0.041266                 NaN              0.067215
#
# [5 rows x 23 columns]
